# %% [markdown]
# <a href="https://colab.research.google.com/github/NareshASU/Foundations-of-Stats-and-Probability-for-AI-and-ML/blob/main/Central_Tendency.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import statistics

# Function definitions
def calculate_mean(data):
    return statistics.mean(data)

def calculate_median(data):
    return statistics.median(data)

def calculate_mode(data):
    try:
        return statistics.mode(data)
    except statistics.StatisticsError:
        return "No unique mode found"

def calculate_geometric_mean(data):
    return statistics.geometric_mean(data)

def calculate_harmonic_mean(data):
    return statistics.harmonic_mean(data)


# Main Program Loop
while True:
    print("\nCentral Tendency Calculator")
    print("1. Mean")
    print("2. Median")
    print("3. Mode")
    print("4. Geometric Mean")
    print("5. Harmonic Mean")
    print("6. Exit")

    choice = input("Enter your choice (1-6): ")

    if choice == "6":
        print("Exiting program... Goodbye! 👋")
        break

    # User enters dataset
    try:
        data = list(map(float, input("Enter numbers separated by space: ").split()))
    except ValueError:
        print("⚠️ Invalid input! Please enter numeric values only.")
        continue

    if choice == "1":
        print("Mean:", calculate_mean(data))
    elif choice == "2":
        print("Median:", calculate_median(data))
    elif choice == "3":
        print("Mode:", calculate_mode(data))
    elif choice == "4":
        print("Geometric Mean:", calculate_geometric_mean(data))
    elif choice == "5":
        print("Harmonic Mean:", calculate_harmonic_mean(data))
    else:
        print("⚠️ Invalid Choice! Please select between 1–6.")
# Out:
# Central Tendency Calculator
# 1. Mean
# 2. Median
# 3. Mode
# 4. Geometric Mean
# 5. Harmonic Mean
# 6. Exit
# Mean: 22.428571428571427
#
# Central Tendency Calculator
# 1. Mean
# 2. Median
# 3. Mode
# 4. Geometric Mean
# 5. Harmonic Mean
# 6. Exit
# Median: 56.0
#
# Central Tendency Calculator
# 1. Mean
# 2. Median
# 3. Mode
# 4. Geometric Mean
# 5. Harmonic Mean
# 6. Exit
# ⚠️ Invalid Choice! Please select between 1–6.
#
# Central Tendency Calculator
# 1. Mean
# 2. Median
# 3. Mode
# 4. Geometric Mean
# 5. Harmonic Mean
# 6. Exit
# Median: 28.5
#
# Central Tendency Calculator
# 1. Mean
# 2. Median
# 3. Mode
# 4. Geometric Mean
# 5. Harmonic Mean
# 6. Exit
# Mode: 45.0
#
# Central Tendency Calculator
# 1. Mean
# 2. Median
# 3. Mode
# 4. Geometric Mean
# 5. Harmonic Mean
# 6. Exit
# Geometric Mean: 385.73397217493135
#
# Central Tendency Calculator
# 1. Mean
# 2. Median
# 3. Mode
# 4. Geometric Mean
# 5. Harmonic Mean
# 6. Exit
# Harmonic Mean: 326.42279987973
#
# ...

# %%
import statistics

# Function definitions
def calculate_mean(data):
    return statistics.mean(data)

def calculate_median(data):
    return statistics.median(data)

def calculate_mode(data):
    try:
        return statistics.mode(data)
    except statistics.StatisticsError:
        return "No unique mode found"

def calculate_geometric_mean(data):
    return statistics.geometric_mean(data)

def calculate_harmonic_mean(data):
    return statistics.harmonic_mean(data)


# Main Program Loop
while True:
    print("\nCentral Tendency Calculator")
    print("1. Mean")
    print("2. Median")
    print("3. Mode")
    print("4. Geometric Mean")
    print("5. Harmonic Mean")
    print("6. Exit")

    choice = input("Enter your choice (1-6): ")

    if choice == "6":
        print("Exiting program... Goodbye! 👋")
        break

    # User enters dataset
    try:
        data = list(map(float, input("Enter numbers separated by space: ").split()))
    except ValueError:
        print("⚠️ Invalid input! Please enter numeric values only.")
        continue

    if choice == "1":
        print("Mean:", calculate_mean(data))
    elif choice == "2":
        print("Median:", calculate_median(data))
    elif choice == "3":
        print("Mode:", calculate_mode(data))
    elif choice == "4":
        print("Geometric Mean:", calculate_geometric_mean(data))
    elif choice == "5":
        print("Harmonic Mean:", calculate_harmonic_mean(data))
    else:
        print("⚠️ Invalid Choice! Please select between 1–6.")
# Out:
# Central Tendency Calculator
# 1. Mean
# 2. Median
# 3. Mode
# 4. Geometric Mean
# 5. Harmonic Mean
# 6. Exit
# Enter your choice (1-6): 6
# Exiting program... Goodbye! 👋

# %%
import statistics

# Function definitions
def calculate_mean(data):
    return statistics.mean(data)

def calculate_median(data):
    return statistics.median(data)

def calculate_mode(data):
    try:
        return statistics.mode(data)
    except statistics.StatisticsError:
        return "No unique mode found"

def calculate_geometric_mean(data):
    return statistics.geometric_mean(data)

def calculate_harmonic_mean(data):
    return statistics.harmonic_mean(data)


# Main Program Loop
while True:
    print("\nCentral Tendency Calculator")
    print("1. Mean")
    print("2. Median")
    print("3. Mode")
    print("4. Geometric Mean")
    print("5. Harmonic Mean")
    print("6. Exit")

    choice = input("Enter your choice (1-6): ")

    if choice == "6":
        print("Exiting program... Goodbye! 👋")
        break

    # User enters dataset
    try:
        data = list(map(float, input("Enter numbers separated by space: ").split()))
    except ValueError:
        print("⚠️ Invalid input! Please enter numeric values only.")
        continue

    if choice == "1":
        print("Mean:", calculate_mean(data))
    elif choice == "2":
        print("Median:", calculate_median(data))
    elif choice == "3":
        print("Mode:", calculate_mode(data))
    elif choice == "4":
        print("Geometric Mean:", calculate_geometric_mean(data))
    elif choice == "5":
        print("Harmonic Mean:", calculate_harmonic_mean(data))
    else:
        print("⚠️ Invalid Choice! Please select between 1–6.")
# Out:
# Central Tendency Calculator
# 1. Mean
# 2. Median
# 3. Mode
# 4. Geometric Mean
# 5. Harmonic Mean
# 6. Exit
# Enter your choice (1-6): 1
# Enter numbers separated by space: 6 9 69 96
# Mean: 45.0
#
# Central Tendency Calculator
# 1. Mean
# 2. Median
# 3. Mode
# 4. Geometric Mean
# 5. Harmonic Mean
# 6. Exit
# Enter your choice (1-6): 2
# Enter numbers separated by space: 66778t88775445
# ⚠️ Invalid input! Please enter numeric values only.
#
# Central Tendency Calculator
# 1. Mean
# 2. Median
# 3. Mode
# 4. Geometric Mean
# 5. Harmonic Mean
# 6. Exit
# Enter your choice (1-6): 6
# Exiting program... Goodbye! 👋
